# %%
import pandas as pd 
import numpy as np

# %%
data={"name":["mitesh","harakh","hiren"],
    "surname":["rana","vahgela","sapra"],
    "salary":[20000,34000,30000],
     "age":[12,23,45]}

# %%
data
# Out:
# {'name': ['mitesh', 'harakh', 'hiren'],
#  'surname': ['rana', 'vahgela', 'sapra'],
#  'salary': [20000, 34000, 30000],
#  'age': [12, 23, 45]}

# %%
df=pd.DataFrame(data)

# %%
df
# Out:
#      name  surname  salary  age
# 0  mitesh     rana   20000   12
# 1  harakh  vahgela   34000   23
# 2   hiren    sapra   30000   45

# %%
df["total"]=df["salary"]/df["age"]

# %%
df
# Out:
#      name  surname  salary  age        total
# 0  mitesh     rana   20000   12  1666.666667
# 1  harakh  vahgela   34000   23  1478.260870
# 2   hiren    sapra   30000   45   666.666667

# %%
df["a"]=[23,45,67]

# %%
df
# Out:
#      name  surname  salary  age        total   a
# 0  mitesh     rana   20000   12  1666.666667  23
# 1  harakh  vahgela   34000   23  1478.260870  45
# 2   hiren    sapra   30000   45   666.666667  67

# %%
df1=pd.DataFrame(data)

# %%
df1
# Out:
#      name  surname  salary  age
# 0  mitesh     rana   20000   12
# 1  harakh  vahgela   34000   23
# 2   hiren    sapra   30000   45

# %%
df=pd.concat([df,df1])

# %%
df
# Out:
#      name  surname  salary  age        total     a
# 0  mitesh     rana   20000   12  1666.666667  23.0
# 1  harakh  vahgela   34000   23  1478.260870  45.0
# 2   hiren    sapra   30000   45   666.666667  67.0
# 0  mitesh     rana   20000   12          NaN   NaN
# 1  harakh  vahgela   34000   23          NaN   NaN
# 2   hiren    sapra   30000   45          NaN   NaN

# %%
df=df.reset_index()

# %%
df.drop(["index"],axis=1,inplace=True)

# %%
df
# Out:
#      name  surname  salary  age        total     a
# 0  mitesh     rana   20000   12  1666.666667  23.0
# 1  harakh  vahgela   34000   23  1478.260870  45.0
# 2   hiren    sapra   30000   45   666.666667  67.0
# 3  mitesh     rana   20000   12          NaN   NaN
# 4  harakh  vahgela   34000   23          NaN   NaN
# 5   hiren    sapra   30000   45          NaN   NaN

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 6 entries, 0 to 5
# Data columns (total 6 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   name     6 non-null      object
#  1   surname  6 non-null      object
#  2   salary   6 non-null      int64
#  3   age      6 non-null      int64
#  4   total    3 non-null      float64
#  5   a        3 non-null      float64
# dtypes: float64(2), int64(2), object(2)
# memory usage: 420.0+ bytes

# %%
df.describe()
# Out:
#              salary        age        total     a
# count      6.000000   6.000000     3.000000   3.0
# mean   28000.000000  26.666667  1270.531401  45.0
# std     6449.806199  15.028861   531.379007  22.0
# min    20000.000000  12.000000   666.666667  23.0
# 25%    22500.000000  14.750000  1072.463768  34.0
# 50%    30000.000000  23.000000  1478.260870  45.0
# 75%    33000.000000  39.500000  1572.463768  56.0
# max    34000.000000  45.000000  1666.666667  67.0

# %%
df.isna().sum()
# Out:
# name       0
# surname    0
# salary     0
# age        0
# total      3
# a          3
# dtype: int64

# %%
df.shape
# Out:
# (6, 6)

# %%
df.columns
# Out:
# Index(['name', 'surname', 'salary', 'age', 'total', 'a'], dtype='object')

# %%
df.index
# Out:
# RangeIndex(start=0, stop=6, step=1)

# %%
df
# Out:
#      name  surname  salary  age        total     a
# 0  mitesh     rana   20000   12  1666.666667  23.0
# 1  harakh  vahgela   34000   23  1478.260870  45.0
# 2   hiren    sapra   30000   45   666.666667  67.0
# 3  mitesh     rana   20000   12          NaN   NaN
# 4  harakh  vahgela   34000   23          NaN   NaN
# 5   hiren    sapra   30000   45          NaN   NaN

# %%
df["name"].value_counts()
# Out:
# name
# mitesh    2
# harakh    2
# hiren     2
# Name: count, dtype: int64

# %%
df.name.sum()
# Out:
# 'miteshharakhhirenmiteshharakhhiren'

# %%
df.name.nunique()
# Out:
# 3

# %%
df.name.unique()
# Out:
# array(['mitesh', 'harakh', 'hiren'], dtype=object)

# %%
df.name.unique()
# Out:
# array(['mitesh', 'harakh', 'hiren'], dtype=object)

# %%
len(df.name)
# Out:
# 6

# %%
df
# Out:
#      name  surname  salary  age        total     a
# 0  mitesh     rana   20000   12  1666.666667  23.0
# 1  harakh  vahgela   34000   23  1478.260870  45.0
# 2   hiren    sapra   30000   45   666.666667  67.0
# 3  mitesh     rana   20000   12          NaN   NaN
# 4  harakh  vahgela   34000   23          NaN   NaN
# 5   hiren    sapra   30000   45          NaN   NaN

# %%
df.loc[df["name"]=="mitesh"]
# Out:
#      name surname  salary  age        total     a
# 0  mitesh    rana   20000   12  1666.666667  23.0
# 3  mitesh    rana   20000   12          NaN   NaN

# %%
df.loc[df["age"]>21]
# Out:
#      name  surname  salary  age        total     a
# 1  harakh  vahgela   34000   23  1478.260870  45.0
# 2   hiren    sapra   30000   45   666.666667  67.0
# 4  harakh  vahgela   34000   23          NaN   NaN
# 5   hiren    sapra   30000   45          NaN   NaN

# %%
df
# Out:
#       name  surname  salary  age        total     a         toal
# 0   mitesh     rana   20000   12  1666.666667  23.0  1666.666667
# 1  darshan  vahgela   34000   23  1478.260870  45.0  1478.260870
# 2    hiren    sapra   30000   45   666.666667  67.0   666.666667
# 3   mitesh     rana   20000   12     6.000000   NaN     0.000000
# 4   harakh  vahgela   34000   23     5.000000   NaN     0.000000
# 5   mitesh    sapra   30000   45          NaN   NaN     0.000000

# %%
df.iloc[3:6,1:3]
# Out:
#    surname  salary
# 3     rana   20000
# 4  vahgela   34000
# 5    sapra   30000

# %%
df
# Out:
#      name  surname  salary  age        total     a
# 0  mitesh     rana   20000   12  1666.666667  23.0
# 1  harakh  vahgela   34000   23  1478.260870  45.0
# 2   hiren    sapra   30000   45   666.666667  67.0
# 3  mitesh     rana   20000   12          NaN   NaN
# 4  harakh  vahgela   34000   23          NaN   NaN
# 5   hiren    sapra   30000   45          NaN   NaN

# %%
df.iloc[4:6,4:6]
# Out:
#    total   a
# 4    NaN NaN
# 5    NaN NaN

# %%
df["toal"]=df["total"].fillna(0)

# %%
df
# Out:
#      name  surname  salary  age        total     a         toal
# 0  mitesh     rana   20000   12  1666.666667  23.0  1666.666667
# 1  harakh  vahgela   34000   23  1478.260870  45.0  1478.260870
# 2   hiren    sapra   30000   45   666.666667  67.0   666.666667
# 3  mitesh     rana   20000   12          NaN   NaN     0.000000
# 4  harakh  vahgela   34000   23          NaN   NaN     0.000000
# 5   hiren    sapra   30000   45          NaN   NaN     0.000000

# %%
df["a"].mean()
# Out:
# 45.0

# %%
df.iloc[4:5,:1]
# Out:
#      name
# 4  harakh

# %%
df.iloc[1:2,:1]=df.iloc[1:2,:1].replace("harakh","darshan")

# %%
df
# Out:
#       name  surname  salary  age        total     a         toal
# 0   mitesh     rana   20000   12  1666.666667  23.0  1666.666667
# 1  darshan  vahgela   34000   23  1478.260870  45.0  1478.260870
# 2    hiren    sapra   30000   45   666.666667  67.0   666.666667
# 3   mitesh     rana   20000   12          NaN   NaN     0.000000
# 4   harakh  vahgela   34000   23          NaN   NaN     0.000000
# 5    hiren    sapra   30000   45          NaN   NaN     0.000000

# %%
df.rename({"a":"num"},axis=1)
# Out:
#       name  surname  salary  age        total   num         toal
# 0   mitesh     rana   20000   12  1666.666667  23.0  1666.666667
# 1  darshan  vahgela   34000   23  1478.260870  45.0  1478.260870
# 2    hiren    sapra   30000   45   666.666667  67.0   666.666667
# 3   mitesh     rana   20000   12          NaN   NaN     0.000000
# 4   harakh  vahgela   34000   23          NaN   NaN     0.000000
# 5    hiren    sapra   30000   45          NaN   NaN     0.000000

# %%
df.iloc[4:,4:6]
# Out:
#    total   a
# 4    NaN NaN
# 5    NaN NaN

# %%
df.iloc[4:5,4:5]=5

# %%
df
# Out:
#       name  surname  salary  age        total     a         toal
# 0   mitesh     rana   20000   12  1666.666667  23.0  1666.666667
# 1  darshan  vahgela   34000   23  1478.260870  45.0  1478.260870
# 2    hiren    sapra   30000   45   666.666667  67.0   666.666667
# 3   mitesh     rana   20000   12          NaN   NaN     0.000000
# 4   harakh  vahgela   34000   23     5.000000   NaN     0.000000
# 5    hiren    sapra   30000   45          NaN   NaN     0.000000

# %%
df.iloc[3:5,4:5]=df.iloc[3:5,4:5].fillna(6)

# %%
df
# Out:
#       name  surname  salary  age        total     a         toal
# 0   mitesh     rana   20000   12  1666.666667  23.0  1666.666667
# 1  darshan  vahgela   34000   23  1478.260870  45.0  1478.260870
# 2    hiren    sapra   30000   45   666.666667  67.0   666.666667
# 3   mitesh     rana   20000   12     6.000000   NaN     0.000000
# 4   harakh  vahgela   34000   23     5.000000   NaN     0.000000
# 5    hiren    sapra   30000   45          NaN   NaN     0.000000

# %%
df.iloc[5:,:1]=np.nan

# %%
df
# Out:
#       name  surname  salary  age        total     a         toal
# 0   mitesh     rana   20000   12  1666.666667  23.0  1666.666667
# 1  darshan  vahgela   34000   23  1478.260870  45.0  1478.260870
# 2    hiren    sapra   30000   45   666.666667  67.0   666.666667
# 3   mitesh     rana   20000   12     6.000000   NaN     0.000000
# 4   harakh  vahgela   34000   23     5.000000   NaN     0.000000
# 5      NaN    sapra   30000   45          NaN   NaN     0.000000

# %%
df.iloc[5:,:1]=df["name"].mode()[0]

# %%
df
# Out:
#       name  surname  salary  age        total     a         toal
# 0   mitesh     rana   20000   12  1666.666667  23.0  1666.666667
# 1  darshan  vahgela   34000   23  1478.260870  45.0  1478.260870
# 2    hiren    sapra   30000   45   666.666667  67.0   666.666667
# 3   mitesh     rana   20000   12     6.000000   NaN     0.000000
# 4   harakh  vahgela   34000   23     5.000000   NaN     0.000000
# 5   mitesh    sapra   30000   45          NaN   NaN     0.000000

# %%
df
# Out:
#       name  surname  salary  age        total     a         toal
# 0   mitesh     rana   20000   12  1666.666667  23.0  1666.666667
# 1  darshan  vahgela   34000   23  1478.260870  45.0  1478.260870
# 2    hiren    sapra   30000   45   666.666667  67.0   666.666667
# 3   mitesh     rana   20000   12     6.000000   NaN     0.000000
# 4   harakh  vahgela   34000   23     5.000000   NaN     0.000000
# 5   mitesh    sapra   30000   45          NaN   NaN     0.000000

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 6 entries, 0 to 5
# Data columns (total 7 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   name     6 non-null      object
#  1   surname  6 non-null      object
#  2   salary   6 non-null      int64
#  3   age      6 non-null      int64
#  4   total    5 non-null      float64
#  5   a        3 non-null      float64
#  6   toal     6 non-null      float64
# dtypes: float64(3), int64(2), object(2)
# memory usage: 468.0+ bytes
