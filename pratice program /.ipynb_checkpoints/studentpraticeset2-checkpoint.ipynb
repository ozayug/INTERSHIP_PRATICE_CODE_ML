# %% [markdown]
# **Student Perfomace Dataset**

# %%
import pandas as pd 
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.preprocessing import PowerTransformer
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import accuracy_score
import warnings
warnings.filterwarnings("ignore")
from sklearn.preprocessing import StandardScaler, MaxAbsScaler,MinMaxScaler,RobustScaler
from sklearn.model_selection import train_test_split

# %%
df=pd.read_csv("student.csv")

# %%
df
# Out:
#       StudentID  Age  Gender  Ethnicity  ParentalEducation  StudyTimeWeekly  \
# 0          1001   17       1          0                  2        19.833723
# 1          1002   18       0          0                  1        15.408756
# 2          1003   15       0          2                  3         4.210570
# 3          1004   17       1          0                  3        10.028829
# 4          1005   17       1          0                  2         4.672495
# ...         ...  ...     ...        ...                ...              ...
# 2387       3388   18       1          0                  3        10.680555
# 2388       3389   17       0          0                  1         7.583217
# 2389       3390   16       1          0                  2         6.805500
# 2390       3391   16       1          1                  0        12.416653
# 2391       3392   16       1          0                  2        17.819907
#
# ...

# %%
df.drop(["StudentID"],axis=1,inplace=True)

# %%
df
# Out:
#       Age  Gender  Ethnicity  ParentalEducation  StudyTimeWeekly  Absences  \
# 0      17       1          0                  2        19.833723         7
# 1      18       0          0                  1        15.408756         0
# 2      15       0          2                  3         4.210570        26
# 3      17       1          0                  3        10.028829        14
# 4      17       1          0                  2         4.672495        17
# ...   ...     ...        ...                ...              ...       ...
# 2387   18       1          0                  3        10.680555         2
# 2388   17       0          0                  1         7.583217         4
# 2389   16       1          0                  2         6.805500        20
# 2390   16       1          1                  0        12.416653        17
# 2391   16       1          0                  2        17.819907        13
#
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2392 entries, 0 to 2391
# Data columns (total 14 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Age                2392 non-null   int64
#  1   Gender             2392 non-null   int64
#  2   Ethnicity          2392 non-null   int64
#  3   ParentalEducation  2392 non-null   int64
#  4   StudyTimeWeekly    2392 non-null   float64
#  5   Absences           2392 non-null   int64
#  6   Tutoring           2392 non-null   int64
#  7   ParentalSupport    2392 non-null   int64
#  8   Extracurricular    2392 non-null   int64
#  9   Sports             2392 non-null   int64
#  10  Music              2392 non-null   int64
#  11  Volunteering       2392 non-null   int64
#  12  GPA                2392 non-null   float64
#  13  GradeClass         2392 non-null   float64
# dtypes: float64(3), int64(11)
# memory usage: 261.8 KB

# %%
df.isna().sum()
# Out:
# Age                  0
# Gender               0
# Ethnicity            0
# ParentalEducation    0
# StudyTimeWeekly      0
# Absences             0
# Tutoring             0
# ParentalSupport      0
# Extracurricular      0
# Sports               0
# Music                0
# Volunteering         0
# GPA                  0
# GradeClass           0
# dtype: int64

# %%
df.GradeClass.describe()
# Out:
# count    2392.000000
# mean        2.983696
# std         1.233908
# min         0.000000
# 25%         2.000000
# 50%         4.000000
# 75%         4.000000
# max         4.000000
# Name: GradeClass, dtype: float64

# %%
df.StudyTimeWeekly.isna().sum()
# Out:
# 0

# %%
plt.figure(figsize=(5,5))
sns.countplot(x='Gender', data=df)
plt.title('Gender Distribution')
plt.show()

# %%
plt.hist(df['Age'],bins=5,edgecolor='black',color="blue")
plt.title('Age Distribution')
plt.xlabel('Age')
plt.ylabel('count')
# Out:
# Text(0, 0.5, 'count')

# %%
sns.boxplot(x='Gender', y='GPA', data=df)
plt.title('GPA by Gender')
plt.show()

# %%
sns.scatterplot(x='StudyTimeWeekly', y='GPA', data=df)
plt.title('Study Time vs GPA')
plt.show()

# %%
sns.barplot(df,x="Age",y="GPA",hue="Gender")
plt.show()

# %%
corr_matrix = df[['Age', 'StudyTimeWeekly', 'Absences', 'GPA']].corr()
sns.heatmap(corr_matrix, annot=True, cmap='coolwarm')
plt.title('Correlation Matrix')
plt.show()

# %%
sns.distplot(df["GPA"])
# Out:
# <Axes: xlabel='GPA', ylabel='Density'>

# %%
p=PowerTransformer()

# %%
df["GPA"]=p.fit_transform(df[["GPA"]])

# %%
df
# Out:
#       Age  Gender  Ethnicity  ParentalEducation  StudyTimeWeekly  Absences  \
# 0      17       1          0                  2        19.833723         7
# 1      18       0          0                  1        15.408756         0
# 2      15       0          2                  3         4.210570        26
# 3      17       1          0                  3        10.028829        14
# 4      17       1          0                  2         4.672495        17
# ...   ...     ...        ...                ...              ...       ...
# 2387   18       1          0                  3        10.680555         2
# 2388   17       0          0                  1         7.583217         4
# 2389   16       1          0                  2         6.805500        20
# 2390   16       1          1                  0        12.416653        17
# 2391   16       1          0                  2        17.819907        13
#
# ...

# %%
sns.distplot(df[["GPA"]])
plt.show()

# %%
plt.figure(figsize=(8, 6))
sns.countplot(x='Tutoring', data=df,edgecolor='black')
plt.title('Tutoring Participation')
plt.xlabel('Tutoring')
plt.ylabel('Count')
plt.show()

# %%
#sns.pairplot(df,hue="GPA")
#plt.show()

# %%
plt.pie(df["Age"].value_counts().values,labels=df["Age"].value_counts().index,autopct='%0.0f%%',shadow=True,explode=(0.3,0,0,0))
plt.show()

# %%
plt.scatter(df["Absences"],df["GPA"])

# %%
sns.jointplot(df,x="Absences",y="Tutoring",hue="GPA")

# %%
df.drop(["Gender","Ethnicity","ParentalEducation","Tutoring","ParentalSupport","Extracurricular","Sports","Music","Volunteering","GradeClass"],axis=1,inplace=True)

# %%
x=df.drop("Absences",axis=1)

# %%
y=df["Absences"]

# %%
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.3,random_state=21)

# %%
s=StandardScaler()

# %%
x_train_s=s.fit_transform(x_train)
x_test_s=s.fit_transform(x_test)

# %%
x_train_s
# Out:
# array([[-0.42822692, -0.8349713 ,  0.5834797 ],
#        [-0.42822692, -0.37718834, -0.69596836],
#        [ 1.34396559,  0.43379657,  0.932856  ],
#        ...,
#        [-1.31432318,  1.58111959,  1.01543622],
#        [-1.31432318,  0.10595146,  0.48060513],
#        [ 1.34396559, -0.87731654, -0.27802096]])

# %%
c=s.get_feature_names_out()

# %%
x_train_s=pd.DataFrame(x_train_s,columns=c)

# %%
np.round(x_train_s.describe(),2)
# Out:
#            Age  StudyTimeWeekly      GPA
# count  1674.00          1674.00  1674.00
# mean     -0.00            -0.00     0.00
# std       1.00             1.00     1.00
# min      -1.31            -1.74    -2.21
# 25%      -1.31            -0.84    -0.78
# 50%      -0.43            -0.01    -0.00
# 75%       0.46             0.82     0.79
# max       1.34             1.82     2.17

# %%
fig,(a1,a2)=plt.subplots(ncols=2,figsize=(12,5))
a1.scatter(x_train["StudyTimeWeekly"],x_train["GPA"])
a1.set_title("Before scalling")
a2.scatter(x_train_s["StudyTimeWeekly"],x_train_s["GPA"],color="black")
a2.set_title("After scalling")
plt.show()

# %%
m=MaxAbsScaler()

# %%
x_train_m=m.fit_transform(x_train)
x_test_m=m.fit_transform(x_test)

# %%
x_train_m
# Out:
# array([[ 0.88888889,  0.25374896,  0.27086866],
#        [ 0.88888889,  0.38248688, -0.3115323 ],
#        [ 1.        ,  0.61055239,  0.42990371],
#        ...,
#        [ 0.83333333,  0.93320305,  0.46749398],
#        [ 0.83333333,  0.51835566,  0.22404046],
#        [ 1.        ,  0.24184062, -0.12128388]])

# %%
h=m.get_feature_names_out()

# %%
x_test_m=pd.DataFrame(x_train_m,columns=h)

# %%
np.round(x_test_m.describe(),2)
# Out:
#            Age  StudyTimeWeekly      GPA
# count  1674.00          1674.00  1674.00
# mean      0.92             0.49     0.01
# std       0.06             0.28     0.46
# min       0.83             0.00    -1.00
# 25%       0.83             0.25    -0.35
# 50%       0.89             0.48     0.01
# 75%       0.94             0.72     0.37
# max       1.00             1.00     0.99

# %%
fig,(a1,a2)=plt.subplots(ncols=2,figsize=(12,5))
a1.scatter(x_test["StudyTimeWeekly"],x_test["GPA"])
a1.set_title("Before scalling"),
a2.scatter(x_test_m["StudyTimeWeekly"],x_test_m["GPA"],color="red")
a2.set_title("After scalling")
plt.show()

# %%
r=RobustScaler()

# %%
x_train_r=r.fit_transform(x_train)
x_test_r=r.fit_transform(x_test)

# %%
x_train_r
# Out:
# array([[ 0.        , -0.49616275,  0.37072831],
#        [ 0.        , -0.21940529, -0.44162516],
#        [ 1.        ,  0.2708841 ,  0.59255603],
#        ...,
#        [-0.5       ,  0.9645102 ,  0.64498827],
#        [-0.5       ,  0.07268192,  0.30541068],
#        [ 1.        , -0.52176301, -0.17625994]])

# %%
y=r.get_feature_names_out()

# %%
x_test_r=pd.DataFrame(x_train_r,columns=y)

# %%
np.round(x_test_r.describe(),2)
# Out:
#            Age  StudyTimeWeekly      GPA
# count  1674.00          1674.00  1674.00
# mean      0.24             0.01     0.00
# std       0.56             0.60     0.64
# min      -0.50            -1.04    -1.40
# 25%      -0.50            -0.50    -0.50
# 50%       0.00            -0.00     0.00
# 75%       0.50             0.50     0.50
# max       1.00             1.11     1.38

# %%
fig,(a1,a2)=plt.subplots(ncols=2,figsize=(12,5))
a1.scatter(x_test["StudyTimeWeekly"],x_test["GPA"])
a1.set_title("Before scalling"),
a2.scatter(x_test_r["StudyTimeWeekly"],x_test_r["GPA"],color="red")
a2.set_title("After scalling")
plt.show()

# %%
n=MinMaxScaler()

# %%
x_train_n=n.fit_transform(x_train)
x_test_n=n.fit_transform(x_test)

# %%
x_train_n
# Out:
# array([[0.33333333, 0.25356738, 0.63754678],
#        [0.33333333, 0.38233662, 0.34537823],
#        [1.        , 0.61045763, 0.71732865],
#        ...,
#        [0.        , 0.9331868 , 0.73618627],
#        [0.        , 0.51823846, 0.61405484],
#        [1.        , 0.24165613, 0.44081867]])

# %%
z=n.get_feature_names_out()

# %%
x_test_n=pd.DataFrame(x_train_n,columns=z)

# %%
np.round(x_test_n.describe(),2)
# Out:
#            Age  StudyTimeWeekly      GPA
# count  1674.00          1674.00  1674.00
# mean      0.49             0.49     0.50
# std       0.38             0.28     0.23
# min       0.00             0.00     0.00
# 25%       0.00             0.25     0.33
# 50%       0.33             0.48     0.50
# 75%       0.67             0.72     0.68
# max       1.00             1.00     1.00

# %%
fig,(a1,a2)=plt.subplots(ncols=2,figsize=(12,5))
a1.scatter(x_test["StudyTimeWeekly"],x_test["GPA"])
a1.set_title("Before scalling")
a2.scatter(x_test_n["StudyTimeWeekly"],x_test_n["GPA"],color="red")
a2.set_title("After scalling")
plt.show()
