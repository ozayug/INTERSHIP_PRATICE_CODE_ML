# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.preprocessing import PowerTransformer
import warnings
warnings.filterwarnings("ignore")

# %%
df=pd.read_csv("tested.csv")

# %%
df
# Out:
#      PassengerId  Survived  Pclass  \
# 0            892         0       3
# 1            893         1       3
# 2            894         0       2
# 3            895         0       3
# 4            896         1       3
# ..           ...       ...     ...
# 413         1305         0       3
# 414         1306         1       1
# 415         1307         0       3
# 416         1308         0       3
# 417         1309         0       3
#
#                                              Name     Sex   Age  SibSp  Parch  \
# 0                                Kelly, Mr. James    male  34.5      0      0
# 1                Wilkes, Mrs. James (Ellen Needs)  female  47.0      1      0
# 2                       Myles, Mr. Thomas Francis    male  62.0      0      0
# 3                                Wirz, Mr. Albert    male  27.0      0      0
# 4    Hirvonen, Mrs. Alexander (Helga E Lindqvist)  female  22.0      1      1
# ...

# %%
sns.distplot(df["Fare"])
# Out:
# <Axes: xlabel='Fare', ylabel='Density'>

# %%
p=PowerTransformer()

# %%
df["Fare"]=p.fit_transform(df[["Fare"]])

# %%
df
# Out:
#      PassengerId  Survived  Pclass  \
# 0            892         0       3
# 1            893         1       3
# 2            894         0       2
# 3            895         0       3
# 4            896         1       3
# ..           ...       ...     ...
# 413         1305         0       3
# 414         1306         1       1
# 415         1307         0       3
# 416         1308         0       3
# 417         1309         0       3
#
#                                              Name     Sex   Age  SibSp  Parch  \
# 0                                Kelly, Mr. James    male  34.5      0      0
# 1                Wilkes, Mrs. James (Ellen Needs)  female  47.0      1      0
# 2                       Myles, Mr. Thomas Francis    male  62.0      0      0
# 3                                Wirz, Mr. Albert    male  27.0      0      0
# 4    Hirvonen, Mrs. Alexander (Helga E Lindqvist)  female  22.0      1      1
# ...

# %%
sns.distplot(df["Fare"])
# Out:
# <Axes: xlabel='Fare', ylabel='Density'>

# %%
df1=pd.read_csv("sales.csv")

# %%
df1
# Out:
#                                Region                Country        Item Type  \
# 0               Australia and Oceania                 Tuvalu        Baby Food
# 1   Central America and the Caribbean                Grenada           Cereal
# 2                              Europe                 Russia  Office Supplies
# 3                  Sub-Saharan Africa  Sao Tome and Principe           Fruits
# 4                  Sub-Saharan Africa                 Rwanda  Office Supplies
# ..                                ...                    ...              ...
# 95                 Sub-Saharan Africa                   Mali          Clothes
# 96                               Asia               Malaysia           Fruits
# 97                 Sub-Saharan Africa           Sierra Leone       Vegetables
# 98                      North America                 Mexico    Personal Care
# 99                 Sub-Saharan Africa             Mozambique        Household
#
# ...

# %%
df1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 100 entries, 0 to 99
# Data columns (total 14 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Region          100 non-null    object
#  1   Country         100 non-null    object
#  2   Item Type       100 non-null    object
#  3   Sales Channel   100 non-null    object
#  4   Order Priority  100 non-null    object
#  5   Order Date      100 non-null    object
#  6   Order ID        100 non-null    int64
#  7   Ship Date       100 non-null    object
#  8   Units Sold      100 non-null    int64
#  9   Unit Price      100 non-null    float64
#  10  Unit Cost       100 non-null    float64
#  11  Total Revenue   100 non-null    float64
#  12  Total Cost      100 non-null    float64
#  13  Total Profit    100 non-null    float64
# dtypes: float64(5), int64(2), object(7)
# memory usage: 11.1+ KB

# %%
df1.describe()
# Out:
#            Order ID   Units Sold  Unit Price   Unit Cost  Total Revenue  \
# count  1.000000e+02   100.000000  100.000000  100.000000   1.000000e+02
# mean   5.550204e+08  5128.710000  276.761300  191.048000   1.373488e+06
# std    2.606153e+08  2794.484562  235.592241  188.208181   1.460029e+06
# min    1.146066e+08   124.000000    9.330000    6.920000   4.870260e+03
# 25%    3.389225e+08  2836.250000   81.730000   35.840000   2.687212e+05
# 50%    5.577086e+08  5382.500000  179.880000  107.275000   7.523144e+05
# 75%    7.907551e+08  7369.000000  437.200000  263.330000   2.212045e+06
# max    9.940222e+08  9925.000000  668.270000  524.960000   5.997055e+06
#
#          Total Cost  Total Profit
# count  1.000000e+02  1.000000e+02
# mean   9.318057e+05  4.416820e+05
# std    1.083938e+06  4.385379e+05
# min    3.612240e+03  1.258020e+03
# 25%    1.688680e+05  1.214436e+05
# 50%    3.635664e+05  2.907680e+05
# 75%    1.613870e+06  6.358288e+05
# max    4.509794e+06  1.719922e+06

# %%
df1.isna().sum()
# Out:
# Region            0
# Country           0
# Item Type         0
# Sales Channel     0
# Order Priority    0
# Order Date        0
# Order ID          0
# Ship Date         0
# Units Sold        0
# Unit Price        0
# Unit Cost         0
# Total Revenue     0
# Total Cost        0
# Total Profit      0
# dtype: int64

# %%
df1.count()
# Out:
# Region            100
# Country           100
# Item Type         100
# Sales Channel     100
# Order Priority    100
# Order Date        100
# Order ID          100
# Ship Date         100
# Units Sold        100
# Unit Price        100
# Unit Cost         100
# Total Revenue     100
# Total Cost        100
# Total Profit      100
# dtype: int64

# %%
df1
# Out:
#                                Region                Country        Item Type  \
# 0               Australia and Oceania                 Tuvalu        Baby Food
# 1   Central America and the Caribbean                Grenada           Cereal
# 2                              Europe                 Russia  Office Supplies
# 3                  Sub-Saharan Africa  Sao Tome and Principe           Fruits
# 4                  Sub-Saharan Africa                 Rwanda  Office Supplies
# ..                                ...                    ...              ...
# 95                 Sub-Saharan Africa                   Mali          Clothes
# 96                               Asia               Malaysia           Fruits
# 97                 Sub-Saharan Africa           Sierra Leone       Vegetables
# 98                      North America                 Mexico    Personal Care
# 99                 Sub-Saharan Africa             Mozambique        Household
#
# ...

# %%
summary = df1.groupby('Sales Channel').sum()

# %%
summary
# Out:
#                                                           Region  \
# Sales Channel
# Offline        Australia and OceaniaEuropeSub-Saharan AfricaS...
# Online         Central America and the CaribbeanSub-Saharan A...
#
#                                                          Country  \
# Sales Channel
# Offline        TuvaluRussiaRwandaAngolaRepublic of the CongoC...
# Online         GrenadaSao Tome and PrincipeSolomon IslandsBur...
#
#                                                        Item Type  \
# Sales Channel
# Offline        Baby FoodOffice SuppliesOffice SuppliesHouseho...
# Online         CerealFruitsBaby FoodVegetablesCerealVegetable...
#
#                                                   Order Priority  \
# Sales Channel
# Offline        HLLMMHHCMCLCLMCHLHHCCMHCHHHHHHLMHLLCCHLLCMCHHC...
# Online         CCCHHHLMLLHLHLHMLCMLMLMHMHHCMCLMCLLMMLCHCHLHLL...
#
#                                                       Order Date     Order ID  \
# Sales Channel
# ...

# %%
plt.bar(df1["Sales Channel"].value_counts().index,df1["Sales Channel"].value_counts().values)
plt.title("bar_graph")
plt.xlabel('Sales Channel')
plt.ylabel('Amount')
plt.show()

# %%
summary = df1.groupby('Item Type').sum()

# %%
summary
# Out:
#                                                             Region  \
# Item Type
# Baby Food        Australia and OceaniaAustralia and OceaniaEuro...
# Beverages        Sub-Saharan AfricaEuropeSub-Saharan AfricaAust...
# Cereal           Central America and the CaribbeanSub-Saharan A...
# Clothes          Sub-Saharan AfricaAsiaEuropeAsiaEuropeEuropeSu...
# Cosmetics        AsiaEuropeEuropeMiddle East and North AfricaEu...
# Fruits           Sub-Saharan AfricaAustralia and OceaniaAustral...
# Household        Sub-Saharan AfricaCentral America and the Cari...
# Meat                       Australia and OceaniaSub-Saharan Africa
# Office Supplies  EuropeSub-Saharan AfricaAustralia and OceaniaA...
# Personal Care    Sub-Saharan AfricaAsiaEuropeSub-Saharan Africa...
# Snacks           Central America and the CaribbeanSub-Saharan A...
# Vegetables       Sub-Saharan AfricaAsiaEuropeAsiaSub-Saharan Af...
#
#                                                            Country  \
# Item Type
# ...

# %%
plt.figure(figsize=(16,10))
plt.bar(df1["Item Type"].value_counts().index,df1["Item Type"].value_counts().values)
plt.title('Total Revenue by Item Type')
plt.xlabel('Item Type')
plt.ylabel('Total Revenue')
plt.show()

# %%
sns.pairplot(df1,hue="Order Date")

# %%
plt.pie(df1["Region"].value_counts().values,labels=df1["Region"].value_counts().index,autopct='%0.0f%%',shadow=True,explode=(0.3,0,0,0,0,0,0))
plt.show()

# %%
plt.scatter(df1["Unit Price"],df1["Unit Cost"])

# %%
df1['Order Date'] = pd.to_datetime(df1['Order Date'])

# %%
df1["Order Date"]
# Out:
# 0    2010-05-28
# 1    2012-08-22
# 2    2014-05-02
# 3    2014-06-20
# 4    2013-02-01
#         ...
# 95   2011-07-26
# 96   2011-11-11
# 97   2016-06-01
# 98   2015-07-30
# 99   2012-02-10
# Name: Order Date, Length: 100, dtype: datetime64[ns]

# %%
df1.sort_values('Order Date', inplace=True)

# %%
revenue_by_date = df1.groupby('Order Date')['Total Revenue'].sum()

# %%
revenue_by_date
# Out:
# Order Date
# 2010-02-02     247956.32
# 2010-02-06    3162704.80
# 2010-05-07      54319.26
# 2010-05-28    2533654.00
# 2010-06-30    1082418.40
#                  ...
# 2017-02-25    1117953.66
# 2017-03-11     246415.95
# 2017-05-08     523807.57
# 2017-05-20    1780539.20
# 2017-05-22     793518.00
# Name: Total Revenue, Length: 100, dtype: float64

# %%
plt.figure(figsize=(10, 6))
plt.plot(revenue_by_date.index, revenue_by_date.values, marker='o', linestyle='-')
plt.title('Total Revenue Over Time')
plt.xlabel('Order Date')
plt.ylabel('Total Revenue')
# Out:
# Text(0, 0.5, 'Total Revenue')

# %%
plt.figure(figsize=(10, 6))
plt.hist(df1['Units Sold'], bins=30, edgecolor='black')
plt.title('Distribution of Units Sold')
plt.xlabel('Units Sold')
plt.ylabel('Frequency')
# Out:
# Text(0, 0.5, 'Frequency')

# %%
df1
# Out:
#                                Region     Country      Item Type  \
# 50                             Europe     Albania        Clothes
# 41       Middle East and North Africa  Azerbaijan      Cosmetics
# 27                 Sub-Saharan Africa        Mali         Fruits
# 0               Australia and Oceania      Tuvalu      Baby Food
# 56              Australia and Oceania        Fiji        Clothes
# ..                                ...         ...            ...
# 34                 Sub-Saharan Africa    Djibouti         Snacks
# 40                 Sub-Saharan Africa       Niger  Personal Care
# 35  Central America and the Caribbean  Costa Rica  Personal Care
# 73                 Sub-Saharan Africa    Djibouti         Cereal
# 25                             Europe      France      Cosmetics
#
#    Sales Channel Order Priority Order Date   Order ID  Ship Date  Units Sold  \
# 50        Online              C 2010-02-02  385383069  3/18/2010        2269
# ...

# %%
sns.jointplot(df1,x="Unit Cost",y="Total Revenue",hue="Total Profit")

# %%
sns.distplot(df1["Unit Price"])
# Out:
# <Axes: xlabel='Unit Price', ylabel='Density'>
